# %%
# imports
import datetime as dt
import numpy as np
import pandas as pd
import pytz
import sys

# my variables
now = dt.datetime.now(pytz.timezone('US/Pacific'))
datestr = now.strftime('%m%d%y')
print 'script executed at', now

# plotting libs
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
sns.set_style('whitegrid')
# %pylab inline
# Out:
# script executed at 2016-03-14 09:58:16.968084-07:00
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.plot(np.random.randn(100));

# %%
later = dt.datetime.now(pytz.timezone('US/Pacific'))
print 'script completed successfully at', later, '\ntime elapsed:', later-now
# Out:
# script completed successfully at 2016-03-14 09:58:17.162147-07:00
# time elapsed: 0:00:00.194063
